# %%
# %pylab inline
import pandas as pd
from sklearn import linear_model
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
document = pd.read_csv('FuelConsumption.csv')

# %%
document.head(100)
# Out:
#     MODELYEAR   MAKE              MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0        2014  ACURA                ILX      COMPACT         2.0          4
# 1        2014  ACURA                ILX      COMPACT         2.4          4
# 2        2014  ACURA         ILX HYBRID      COMPACT         1.5          4
# 3        2014  ACURA            MDX 4WD  SUV - SMALL         3.5          6
# 4        2014  ACURA            RDX AWD  SUV - SMALL         3.5          6
# ..        ...    ...                ...          ...         ...        ...
# 95       2014    BMW         435i COUPE      COMPACT         3.0          6
# 96       2014    BMW  435i xDRIVE COUPE      COMPACT         3.0          6
# 97       2014    BMW  435i xDRIVE COUPE      COMPACT         3.0          6
# 98       2014    BMW               528i     MID-SIZE         2.0          4
# 99       2014    BMW        528i xDRIVE     MID-SIZE         2.0          4
#
# ...

# %%
cdf = document[['ENGINESIZE' , 'CYLINDERS' , 'FUELCONSUMPTION_CITY' , 'FUELCONSUMPTION_HWY' , 'FUELCONSUMPTION_COMB' , 'CO2EMISSIONS' ]]
cdf.head(len(cdf))
#We notice Fuelconsumption_comb is a resultant vector of fuel_consumption city and fuel_consumption hwy.
#Hence, we consider fuelconsumption_comb instead of both of the other vectors.
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0            2.0          4                   9.9                  6.7
# 1            2.4          4                  11.2                  7.7
# 2            1.5          4                   6.0                  5.8
# 3            3.5          6                  12.7                  9.1
# 4            3.5          6                  12.1                  8.7
# ...          ...        ...                   ...                  ...
# 1062         3.0          6                  13.4                  9.8
# 1063         3.2          6                  13.2                  9.5
# 1064         3.0          6                  13.4                  9.8
# 1065         3.2          6                  12.9                  9.3
# 1066         3.2          6                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0                      8.5           196
# ...

# %%
#Create training and testing datasets
fraction = np.random.random(len(cdf)) < 0.8
train_data = cdf[fraction]
test_data = cdf[~fraction]

print(len(train_data) , len(test_data))
# Out:
# 871 196

# %%
#Get the train_x and train_y axis
train_x = train_data[['ENGINESIZE' , 'CYLINDERS' , 'FUELCONSUMPTION_COMB']]
train_y = train_data[['CO2EMISSIONS']]

# %%
#Build the regression model
regression = linear_model.LinearRegression()

# %%
regression.fit(train_x , train_y)
# Out:
# LinearRegression()

# %%
print("The coefficients of x1, x2 ,x3 are : " , regression.coef_[0])
print("The intercept is : " , regression.intercept_[0])

coef = regression.coef_[0]
intercept = regression.intercept_[0]
# Out:
# The coefficients of x1, x2 ,x3 are :  [11.20605176  7.48969002  9.38105019]
# The intercept is :  66.54851562983364

# %%
y_expected = regression.predict(test_data[['ENGINESIZE' , 'CYLINDERS' , 'FUELCONSUMPTION_COMB']])
print(y_expected)
# Out:
# [[257.07870432]
#  [323.60265191]
#  [206.16314595]
#  [214.60609112]
#  [250.1725731 ]
#  [277.29610991]
#  [224.8437376 ]
#  [247.35825804]
#  [339.57604146]
#  [285.73905508]
#  [378.44843447]
#  [181.77241547]
#  [200.53451584]
#  [241.72962793]
#  [238.91531288]
#  [201.47262086]
#  [204.28693591]
#  [239.8534179 ]
#  [294.91200088]
#  [369.06738429]
#  [232.34857775]
#  [231.41047273]
#  [313.67410125]
#  [212.72988108]
#  [204.28693591]
#  [211.79177606]
#  [349.79277974]
#  [250.32946903]
#  [315.08289406]
#  [334.78309945]
#  [301.01131878]
#  [193.60278039]
#  [335.01680806]
#  [387.5506891 ]
#  [370.06608984]
#  [304.99744747]
#  [344.39785825]
#  [182.55362456]
#  [248.45325899]
#  [218.1504068 ]
#  [316.0466033 ]
#  [290.66798483]
#  [248.45325899]
#  [217.21230179]
#  [250.32946903]
#  [248.45325899]
#  [290.66798483]
#  [256.89620416]
#  [204.07883153]
#  [205.95504156]
#  [325.42765349]
#  [298.17282498]
#  [303.80145509]
#  [193.81088478]
#  [335.61551699]
# ...

# %%
#Mean Square residue calculation

y_real = np.asanyarray(test_data[['CO2EMISSIONS']])
print("Mean sqaure residue is : " , np.mean((y_expected - y_real)**2))
# Out:
# Mean sqaure residue is :  585.5456067346358

# %% [markdown]
# ### Observe
#
# Observe the mean square residue between single variable regression and multiple variable regression!
